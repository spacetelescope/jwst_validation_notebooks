# %% [markdown]
# <a id="title_ID"></a>
# # JWST FGS regression tests
#
# <span style="color:red"> **Instruments Affected**</span>: FGS
# ### Table of Contents
#
# <div style="text-align: left">
#
# <br> [Introduction](#intro)
# <br> [JWST Regression Tests](#unit)
# <br> [Defining Terms](#terms)
# <br> [Test Description](#description)
# <br> [Data Description](#data_descr)
# <br> [Imports](#imports)
# <br> [Convenience Functions](#functions)
# <br> [Perform Tests](#testing)
# <br> [About This Notebook](#about)
# <br>
#
# </div>

# %% [markdown]
# <a id="intro"></a>
# # Introduction
#
# This is the validation notebook that displays the regression tests for the FGS instrument in the JWST calibration pipeline. This notebook runs and displays the regression tests that are performed as a part of the normal software continuous integration process. For more information on the pipeline visit the links below.
#
# * Pipeline description: https://jwst-pipeline.readthedocs.io/en/latest/index.html
#
# * Pipeline code: https://github.com/spacetelescope/jwst
#
# [Top of Page](#title_ID)

# %% [markdown]
# <a id="unit"></a>
# # JWST Regression Tests
#
# JWST regression tests are located in the ```regtest``` folder of the pipeline within the [GitHub repository](https://github.com/spacetelescope/jwst/tree/master/jwst/regtest).
#
# * Regression test README: https://github.com/spacetelescope/jwst#regression-tests
#
#
# [Top of Page](#title_ID)

# %% [markdown]
# <a id="terms"></a>
# # Defining Terms
#
# These are terms or acronymns used in this notebook that may not be known a general audience.
#
# * JWST: James Webb Space Telescope
#
# * FGS: Near-Infrared Camera
#
#
# [Top of Page](#title_ID)

# %% [markdown]
# <a id="description"></a>
# # Test Description
#
# Regression testing is a software testing method which checks if the pipeline step produces the expected outcome by comparing an input file with a truth file. Truth files for testing are stored in Artifactory.
#
#
# [Top of Page](#title_ID)

# %% [markdown]
# <a id="data_descr"></a>
# # Data Description
#
# Data used for regression tests is stored in Artifactory, and consists of a mix of simulated and ground testing data for the different instruments and modes.
#
#
# [Top of Page](#title_ID)

# %% [markdown]
# <a id="imports"></a>
# # Imports
#
# * tempfile for creating temporary output products
# * pytest for unit test functions
# * jwst for the JWST Pipeline
# * IPython.display for display pytest reports
#
# [Top of Page](#title_ID)

# %%
import tempfile
import os
import pytest
import jwst
from IPython.display import IFrame

# %% [markdown]
# <a id="functions"></a>
# # Convenience Functions
#
# Here we define any convenience functions to help with running the unit tests.
#
# [Top of Page](#title_ID)

# %%
def display_report(fname):
    '''Convenience function to display pytest report.'''
    
    return IFrame(src=fname, width=700, height=600)

# %% [markdown]
# <a id="testing"></a>
# # Perform Tests
#
# Below we run the regression tests for the FGS instrument.
#
# [Top of Page](#title_ID)

# %%
jwst_dir = os.path.dirname(jwst.__file__)
regtest = os.path.join(jwst_dir, 'regtest')
associations = os.path.join(jwst_dir, 'associations')
datamodels = os.path.join(jwst_dir, 'datamodels')
stpipe = os.path.join(jwst_dir, 'stpipe')

with tempfile.TemporaryDirectory() as tmpdir:
    # !pytest --bigdata {regtest} -k 'test_fgs' -v --ignore={associations} --ignore={datamodels} --ignore={stpipe} --html=tmpdir/regtest_report.html --self-contained-html
    report = display_report('tmpdir/regtest_report.html')
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.9.1, pytest-6.2.2, py-1.10.0, pluggy-0.13.1 -- /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/miniconda3/envs/jwst_validation_notebooks/bin/python
# cachedir: .pytest_cache
# metadata: {'Python': '3.9.1', 'Platform': 'Linux-3.10.0-1160.11.1.el7.x86_64-x86_64-with-glibc2.17', 'Packages': {'pytest': '6.2.2', 'py': '1.10.0', 'pluggy': '0.13.1'}, 'Plugins': {'metadata': '1.11.0', 'asdf': '2.7.2', 'html': '3.1.1', 'forked': '1.3.0', 'xdist': '2.2.0', 'ci-watson': '0.5'}, 'BUILD_NUMBER': '52', 'BUILD_ID': '52', 'BUILD_URL': 'https://plwishmaster.stsci.edu:8081/job/Notebooks/job/jwst_validation_notebooks_spacetelescope/52/', 'NODE_NAME': 'jwcalibdev.stsci.edu', 'JOB_NAME': 'Notebooks/jwst_validation_notebooks_spacetelescope', 'BUILD_TAG': 'jenkins-Notebooks-jwst_validation_notebooks_spacetelescope-52', 'EXECUTOR_NUMBER': '29', 'JENKINS_URL': 'https://plwishmaster.stsci.edu:8081/', 'WORKSPACE': '/data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope', 'GIT_COMMIT': 'f6ea8bc553cb5ba6998fd20927d8e020dec1e853', 'GIT_URL': 'https://github.com/spacetelescope/jwst_validation_notebooks', 'GIT_BRANCH': 'origin/master'}
# rootdir: /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope
# plugins: metadata-1.11.0, asdf-2.7.2, html-3.1.1, forked-1.3.0, xdist-2.2.0, ci-watson-0.5
# collecting ...
# collecting 157 items
# collected 447 items / 431 deselected / 16 selected
#
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_guider[exptype_fgs_acq1-cal]
# FAILED [  6%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_guider[exptype_fgs_acq1-dq_init]
# FAILED [ 12%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_guider[exptype_fgs_acq1-guider_cds]
# FAILED [ 18%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_guider[exptype_fgs_fineguide-cal]
# PASSED [ 25%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_guider[exptype_fgs_fineguide-dq_init]
# PASSED [ 31%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_guider[exptype_fgs_fineguide-guider_cds]
# PASSED [ 37%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_guider[exptype_fgs_id_image-cal]
# FAILED [ 43%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_guider[exptype_fgs_id_image-dq_init]
# FAILED [ 50%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_guider[exptype_fgs_id_image-guider_cds]
# FAILED [ 56%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_guider[exptype_fgs_id_stack-cal]
# FAILED [ 62%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_guider[exptype_fgs_id_stack-dq_init]
# FAILED [ 68%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_guider[exptype_fgs_id_stack-guider_cds]
# FAILED [ 75%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_toobig
# PASSED [ 81%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_image2.py::test_fgs_image2[jw86500007001_02101_00001_GUIDER2_cal.fits]
# PASSED [ 87%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_image2.py::test_fgs_image2[jw86500007001_02101_00001_GUIDER2_flat_field.fits]
# PASSED [ 93%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_image2.py::test_fgs_image2[jw86500007001_02101_00001_GUIDER2_i2d.fits]
# FAILED [100%]
# =================================== FAILURES ===================================
# ____________________ test_fgs_guider[exptype_fgs_acq1-cal] _____________________
#
# run_guider_pipelines = {'input': '/data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-0/tes...h/exptype_fgs_acq1_cal.fits',
#  'truth_remote': 'jwst-pipeline/dev/truth/fgs/test_fgs_guider/exptype_fgs_acq1_cal.fits'}
# fitsdiff_default_kwargs = {'atol': 1e-07, 'ignore_fields': ['DATE', 'CAL_VER', 'CAL_VCS', 'CRDS_VER', 'CRDS_CTX', 'NAXIS1', ...], 'ignore_hdus': ['ASDF'], 'ignore_keywords': ['DATE', 'CAL_VER', 'CAL_VCS', 'CRDS_VER', 'CRDS_CTX', 'NAXIS1', ...], ...}
# suffix = 'cal'
#     @pytest.mark.bigdata
#     @pytest.mark.parametrize('suffix', guider_suffixes, ids=guider_suffixes)
#     def test_fgs_guider(run_guider_pipelines, fitsdiff_default_kwargs, suffix):
#         """Regression for FGS Guider data"""
# >       rt.is_like_truth(run_guider_pipelines, fitsdiff_default_kwargs, suffix,
#                          'truth/fgs/test_fgs_guider', is_suffix=True)
# E       AssertionError:
# E        fitsdiff: 4.2
# E        a: /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-0/test_fgs_guider_run_guider_pipelines0/exptype_fgs_acq1_cal.fits
# E        b: /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-0/test_fgs_guider_run_guider_pipelines0/truth/exptype_fgs_acq1_cal.fits
# E        HDU(s) not to be compared:
# E         ASDF
# E        Keyword(s) not to be compared:
# E         CAL_VCS CAL_VER CRDS_CTX CRDS_VER DATE NAXIS1 TFORM*
# E        Table column(s) not to be compared:
# E         CAL_VCS CAL_VER CRDS_CTX CRDS_VER DATE NAXIS1 TFORM*
# E        Maximum number of different data values to be reported: 10
# E        Relative tolerance: 1e-05, Absolute tolerance: 1e-07
# E
# E       Primary HDU:
# E
# E          Headers contain differences:
# E            Headers have different number of cards:
# E             a: 147
# E             b: 150
# E            Extra keyword 'VA_DEC' in b: 0.0
# E            Extra keyword 'VA_RA'  in b: 0.0
# E            Inconsistent duplicates of keyword ''      :
# E             Occurs 18 time(s) in a, 19 times in (b)
# E            Keyword         [9] has different values:
# E               a> Time information
# E               b> Velocity aberration correction information
# E            Keyword         [10] has different values:
# E               a> Guide star information
# E               b> Time information
# E            Keyword         [11] has different values:
# E               a> Reference file information
# E               b> Guide star information
# E            Keyword         [12] has different values:
# E               a> CRDS parameters
# E               b> Reference file information
# E            Keyword         [13] has different values:
# E               a> Flat reference file information
# E               b> CRDS parameters
# E            Keyword         [14] has different values:
# E               a> DFlat reference file information
# E                ? -
# E               b> Flat reference file information
# E            Keyword         [15] has different values:
# E               a> FFlat reference file information
# E                ? ^
# E               b> DFlat reference file information
# E                ? ^
# E            Keyword         [16] has different values:
# E               a> SFlat reference file information
# E                ? ^
# E               b> FFlat reference file information
# E                ? ^
# E            Keyword         [17] has different values:
# E               a> Mask reference file information
# E                ? ^ ^^
# E               b> SFlat reference file information
# E                ? ^^^ ^
# E            Keyword         [18] has different values:
# E               a> Calibration step information
# E               b> Mask reference file information
#
# /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py:34: AssertionError
# ---------------------------- Captured stderr setup -----------------------------
# 2021-01-31 20:35:35,789 - stpipe.GuiderPipeline - INFO - GuiderPipeline instance created.
# 2021-01-31 20:35:35,789 - stpipe.GuiderPipeline.dq_init - INFO - DQInitStep instance created.
# 2021-01-31 20:35:35,790 - stpipe.GuiderPipeline.guider_cds - INFO - GuiderCdsStep instance created.
# 2021-01-31 20:35:35,791 - stpipe.GuiderPipeline.flat_field - INFO - FlatFieldStep instance created.
# 2021-01-31 20:35:35,791 - stpipe - INFO - Hostname: jwcalibdev.stsci.edu
# 2021-01-31 20:35:35,791 - stpipe - INFO - OS: Linux
# 2021-01-31 20:35:35,872 - stpipe.GuiderPipeline - INFO - Step GuiderPipeline running with args ('/data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-0/test_fgs_guider_run_guider_pipelines0/exptype_fgs_acq1_uncal.fits',).
# 2021-01-31 20:35:35,874 - stpipe.GuiderPipeline - INFO - Step GuiderPipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-0/test_fgs_guider_run_guider_pipelines0', 'steps': {'dq_init': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-0/test_fgs_guider_run_guider_pipelines0'}, 'guider_cds': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-0/test_fgs_guider_run_guider_pipelines0'}, 'flat_field': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-0/test_fgs_guider_run_guider_pipelines0', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}}}
# 2021-01-31 20:35:35,912 - stpipe.GuiderPipeline - INFO - Prefetching reference files for dataset: 'exptype_fgs_acq1_uncal.fits' reftypes = ['dflat', 'fflat', 'flat', 'mask', 'sflat']
# 2021-01-31 20:35:35,947 - stpipe.GuiderPipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2021-01-31 20:35:35,947 - stpipe.GuiderPipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2021-01-31 20:35:35,947 - stpipe.GuiderPipeline - INFO - Prefetch for FLAT reference file is '/grp/crds/cache/references/jwst/jwst_fgs_flat_0010.fits'.
# 2021-01-31 20:35:35,948 - stpipe.GuiderPipeline - INFO - Prefetch for MASK reference file is '/grp/crds/cache/references/jwst/jwst_fgs_mask_0025.fits'.
# 2021-01-31 20:35:35,949 - stpipe.GuiderPipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2021-01-31 20:35:35,949 - stpipe.GuiderPipeline - INFO - Starting calwebb_guider ...
# 2021-01-31 20:35:36,072 - stpipe.GuiderPipeline.dq_init - INFO - Step dq_init running with args (<GuiderRawModel(6, 2, 128, 128) from exptype_fgs_acq1_uncal.fits>,).
# 2021-01-31 20:35:36,073 - stpipe.GuiderPipeline.dq_init - INFO - Step dq_init parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-0/test_fgs_guider_run_guider_pipelines0'}
# 2021-01-31 20:35:36,088 - stpipe.GuiderPipeline.dq_init - INFO - Input opened as GuiderRawModel
# 2021-01-31 20:35:36,091 - stpipe.GuiderPipeline.dq_init - INFO - Using MASK reference file /grp/crds/cache/references/jwst/jwst_fgs_mask_0025.fits
# 2021-01-31 20:35:36,425 - stpipe.GuiderPipeline.dq_init - WARNING - Keyword FGS_WARM does not correspond to an existing DQ mnemonic, so will be ignored
# 2021-01-31 20:35:36,426 - stpipe.GuiderPipeline.dq_init - WARNING - Keyword FGS_NOISY does not correspond to an existing DQ mnemonic, so will be ignored
# 2021-01-31 20:35:36,462 - stpipe.GuiderPipeline.dq_init - INFO - Extracting mask subarray to match science data
# 2021-01-31 20:35:36,504 - stpipe.GuiderPipeline.dq_init - INFO - Saved model in exptype_fgs_acq1_dq_init.fits
# 2021-01-31 20:35:36,504 - stpipe.GuiderPipeline.dq_init - INFO - Step dq_init done
# 2021-01-31 20:35:36,608 - stpipe.GuiderPipeline.guider_cds - INFO - Step guider_cds running with args (<GuiderRawModel(6, 2, 128, 128) from exptype_fgs_acq1_dq_init.fits>,).
# 2021-01-31 20:35:36,609 - stpipe.GuiderPipeline.guider_cds - INFO - Step guider_cds parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-0/test_fgs_guider_run_guider_pipelines0'}
# 2021-01-31 20:35:36,615 - stpipe.GuiderPipeline.guider_cds - INFO - Instrument: FGS
# 2021-01-31 20:35:36,615 - stpipe.GuiderPipeline.guider_cds - INFO - Exposure type: FGS_ACQ1
# 2021-01-31 20:35:36,615 - stpipe.GuiderPipeline.guider_cds - INFO - Number of integrations: 6
# 2021-01-31 20:35:36,615 - stpipe.GuiderPipeline.guider_cds - INFO - Number of groups per integration: 2
# 2021-01-31 20:35:36,615 - stpipe.GuiderPipeline.guider_cds - INFO - Group time: 0.3612000000000001
# 2021-01-31 20:35:36,616 - stpipe.GuiderPipeline.guider_cds - INFO - Frame time:    0.18060
# 2021-01-31 20:35:36,660 - stpipe.GuiderPipeline.guider_cds - INFO - Saved model in exptype_fgs_acq1_guider_cds.fits
# 2021-01-31 20:35:36,660 - stpipe.GuiderPipeline.guider_cds - INFO - Step guider_cds done
# 2021-01-31 20:35:36,736 - stpipe.GuiderPipeline.flat_field - INFO - Step flat_field running with args (<GuiderCalModel(6, 128, 128) from exptype_fgs_acq1_guider_cds.fits>,).
# 2021-01-31 20:35:36,736 - stpipe.GuiderPipeline.flat_field - INFO - Step flat_field parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-0/test_fgs_guider_run_guider_pipelines0', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}
# 2021-01-31 20:35:37,500 - stpipe.GuiderPipeline.flat_field - INFO - Extracting matching subarray from flat
# 2021-01-31 20:35:37,509 - stpipe.GuiderPipeline.flat_field - INFO - Step flat_field done
# 2021-01-31 20:35:37,509 - stpipe.GuiderPipeline - INFO - ... ending calwebb_guider
# 2021-01-31 20:35:37,539 - stpipe.GuiderPipeline - INFO - Saved model in exptype_fgs_acq1_cal.fits
# 2021-01-31 20:35:37,539 - stpipe.GuiderPipeline - INFO - Step GuiderPipeline done
# ------------------------------ Captured log setup ------------------------------
# DEBUG    stpipe:connectionpool.py:971 Starting new HTTPS connection (1): bytesalad.stsci.edu:443
# DEBUG    stpipe:connectionpool.py:971 Starting new HTTPS connection (1): bytesalad.stsci.edu:443
# DEBUG    stpipe:connectionpool.py:452 https://bytesalad.stsci.edu:443 "GET /artifactory HTTP/1.1" 302 0
# DEBUG    stpipe:connectionpool.py:452 https://bytesalad.stsci.edu:443 "GET /artifactory HTTP/1.1" 302 0
# DEBUG    stpipe:connectionpool.py:452 https://bytesalad.stsci.edu:443 "GET /artifactory/ HTTP/1.1" 302 0
# DEBUG    stpipe:connectionpool.py:452 https://bytesalad.stsci.edu:443 "GET /artifactory/ HTTP/1.1" 302 0
# DEBUG    stpipe:connectionpool.py:452 https://bytesalad.stsci.edu:443 "GET /ui/ HTTP/1.1" 200 1196
# DEBUG    stpipe:connectionpool.py:452 https://bytesalad.stsci.edu:443 "GET /ui/ HTTP/1.1" 200 1196
# DEBUG    stpipe:connectionpool.py:971 Starting new HTTPS connection (1): bytesalad.stsci.edu:443
# DEBUG    stpipe:connectionpool.py:971 Starting new HTTPS connection (1): bytesalad.stsci.edu:443
# DEBUG    stpipe:connectionpool.py:452 https://bytesalad.stsci.edu:443 "GET /artifactory HTTP/1.1" 302 0
# DEBUG    stpipe:connectionpool.py:452 https://bytesalad.stsci.edu:443 "GET /artifactory HTTP/1.1" 302 0
# DEBUG    stpipe:connectionpool.py:452 https://bytesalad.stsci.edu:443 "GET /artifactory/ HTTP/1.1" 302 0
# DEBUG    stpipe:connectionpool.py:452 https://bytesalad.stsci.edu:443 "GET /artifactory/ HTTP/1.1" 302 0
# DEBUG    stpipe:connectionpool.py:452 https://bytesalad.stsci.edu:443 "GET /ui/ HTTP/1.1" 200 1196
# DEBUG    stpipe:connectionpool.py:452 https://bytesalad.stsci.edu:443 "GET /ui/ HTTP/1.1" 200 1196
# DEBUG    stpipe:connectionpool.py:971 Starting new HTTPS connection (1): bytesalad.stsci.edu:443
# DEBUG    stpipe:connectionpool.py:971 Starting new HTTPS connection (1): bytesalad.stsci.edu:443
# DEBUG    stpipe:connectionpool.py:452 https://bytesalad.stsci.edu:443 "GET /artifactory/jwst-pipeline/dev/fgs/level1b/exptype_fgs_acq1_uncal.fits HTTP/1.1" 200 408960
# DEBUG    stpipe:connectionpool.py:452 https://bytesalad.stsci.edu:443 "GET /artifactory/jwst-pipeline/dev/fgs/level1b/exptype_fgs_acq1_uncal.fits HTTP/1.1" 200 408960
# DEBUG    stpipe:connectionpool.py:971 Starting new HTTPS connection (1): bytesalad.stsci.edu:443
# DEBUG    stpipe:connectionpool.py:971 Starting new HTTPS connection (1): bytesalad.stsci.edu:443
# DEBUG    stpipe:connectionpool.py:452 https://bytesalad.stsci.edu:443 "GET /artifactory/jwst-pipeline/dev/fgs/level1b/exptype_fgs_acq1_uncal.fits HTTP/1.1" 200 408960
# DEBUG    stpipe:connectionpool.py:452 https://bytesalad.stsci.edu:443 "GET /artifactory/jwst-pipeline/dev/fgs/level1b/exptype_fgs_acq1_uncal.fits HTTP/1.1" 200 408960
# DEBUG    stpipe:config_parser.py:145 Config file did not parse as ASDF. Trying as ConfigObj: config/calwebb_guider.cfg
# DEBUG    stpipe:config_parser.py:145 Config file did not parse as ASDF. Trying as ConfigObj: config/calwebb_guider.cfg
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:pipeline.py:194 Retrieving all substep parameters from CRDS
# DEBUG    stpipe:pipeline.py:194 Retrieving all substep parameters from CRDS
# DEBUG    stpipe:util.py:188 Opening /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-0/test_fgs_guider_run_guider_pipelines0/exptype_fgs_acq1_uncal.fits as <class 'jwst.datamodels.ramp.RampModel'>
# DEBUG    stpipe:util.py:188 Opening /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-0/test_fgs_guider_run_guider_pipelines0/exptype_fgs_acq1_uncal.fits as <class 'jwst.datamodels.ramp.RampModel'>
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "SKIP_FITS_UPDATE" cannot be found. Using default value of "None".
# DEBUG    stpipe:util.py:175 Environmental "SKIP_FITS_UPDATE" cannot be found. Using default value of "None".
# DEBUG    stpipe:fits_support.py:675 No ASDF information found. Cannot skip updating from FITS headers.
# DEBUG    stpipe:fits_support.py:675 No ASDF information found. Cannot skip updating from FITS headers.
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:pipeline.py:205 Retrieving pipeline PARS-GUIDERPIPELINE parameters from CRDS
# DEBUG    stpipe:pipeline.py:205 Retrieving pipeline PARS-GUIDERPIPELINE parameters from CRDS
# DEBUG    stpipe:pipeline.py:219 No PARS-GUIDERPIPELINE reference files found.
# DEBUG    stpipe:pipeline.py:219 No PARS-GUIDERPIPELINE reference files found.
# INFO     stpipe.GuiderPipeline:step.py:313 GuiderPipeline instance created.
# INFO     stpipe.GuiderPipeline.dq_init:step.py:313 DQInitStep instance created.
# INFO     stpipe.GuiderPipeline.guider_cds:step.py:313 GuiderCdsStep instance created.
# INFO     stpipe.GuiderPipeline.flat_field:step.py:313 FlatFieldStep instance created.
# INFO     stpipe:cmdline.py:296 Hostname: jwcalibdev.stsci.edu
# INFO     stpipe:cmdline.py:296 Hostname: jwcalibdev.stsci.edu
# INFO     stpipe:cmdline.py:297 OS: Linux
# INFO     stpipe:cmdline.py:297 OS: Linux
# INFO     stpipe.GuiderPipeline:step.py:360 Step GuiderPipeline running with args ('/data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-0/test_fgs_guider_run_guider_pipelines0/exptype_fgs_acq1_uncal.fits',).
# INFO     stpipe.GuiderPipeline:step.py:364 Step GuiderPipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-0/test_fgs_guider_run_guider_pipelines0', 'steps': {'dq_init': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-0/test_fgs_guider_run_guider_pipelines0'}, 'guider_cds': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-0/test_fgs_guider_run_guider_pipelines0'}, 'flat_field': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-0/test_fgs_guider_run_guider_pipelines0', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}}}
# DEBUG    stpipe.GuiderPipeline:util.py:188 Opening /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-0/test_fgs_guider_run_guider_pipelines0/exptype_fgs_acq1_uncal.fits as <class 'jwst.datamodels.ramp.RampModel'>
# DEBUG    stpipe.GuiderPipeline:util.py:188 Opening /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-0/test_fgs_guider_run_guider_pipelines0/exptype_fgs_acq1_uncal.fits as <class 'jwst.datamodels.ramp.RampModel'>
# DEBUG    stpipe.GuiderPipeline:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe.GuiderPipeline:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe.GuiderPipeline:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe.GuiderPipeline:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe.GuiderPipeline:util.py:175 Environmental "SKIP_FITS_UPDATE" cannot be found. Using default value of "None".
# DEBUG    stpipe.GuiderPipeline:util.py:175 Environmental "SKIP_FITS_UPDATE" cannot be found. Using default value of "None".
# DEBUG    stpipe.GuiderPipeline:fits_support.py:675 No ASDF information found. Cannot skip updating from FITS headers.
# DEBUG    stpipe.GuiderPipeline:fits_support.py:675 No ASDF information found. Cannot skip updating from FITS headers.
# INFO     stpipe.GuiderPipeline:pipeline.py:318 Prefetching reference files for dataset: 'exptype_fgs_acq1_uncal.fits' reftypes = ['dflat', 'fflat', 'flat', 'mask', 'sflat']
# INFO     stpipe.GuiderPipeline:pipeline.py:326 Prefetch for DFLAT reference file is 'N/A'.
# INFO     stpipe.GuiderPipeline:pipeline.py:326 Prefetch for FFLAT reference file is 'N/A'.
# INFO     stpipe.GuiderPipeline:pipeline.py:326 Prefetch for FLAT reference file is '/grp/crds/cache/references/jwst/jwst_fgs_flat_0010.fits'.
# INFO     stpipe.GuiderPipeline:pipeline.py:326 Prefetch for MASK reference file is '/grp/crds/cache/references/jwst/jwst_fgs_mask_0025.fits'.
# INFO     stpipe.GuiderPipeline:pipeline.py:326 Prefetch for SFLAT reference file is 'N/A'.
# INFO     stpipe.GuiderPipeline:calwebb_guider.py:37 Starting calwebb_guider ...
# INFO     stpipe.GuiderPipeline:calwebb_guider.py:37 Starting calwebb_guider ...
# DEBUG    stpipe.GuiderPipeline:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe.GuiderPipeline:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe.GuiderPipeline:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe.GuiderPipeline:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe.GuiderPipeline:util.py:175 Environmental "SKIP_FITS_UPDATE" cannot be found. Using default value of "None".
# DEBUG    stpipe.GuiderPipeline:util.py:175 Environmental "SKIP_FITS_UPDATE" cannot be found. Using default value of "None".
# DEBUG    stpipe.GuiderPipeline:fits_support.py:675 No ASDF information found. Cannot skip updating from FITS headers.
# DEBUG    stpipe.GuiderPipeline:fits_support.py:675 No ASDF information found. Cannot skip updating from FITS headers.
# INFO     stpipe.GuiderPipeline.dq_init:step.py:360 Step dq_init running with args (<GuiderRawModel(6, 2, 128, 128) from exptype_fgs_acq1_uncal.fits>,).
# INFO     stpipe.GuiderPipeline.dq_init:step.py:364 Step dq_init parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-0/test_fgs_guider_run_guider_pipelines0'}
# DEBUG    stpipe.GuiderPipeline.dq_init:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe.GuiderPipeline.dq_init:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe.GuiderPipeline.dq_init:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe.GuiderPipeline.dq_init:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe.GuiderPipeline.dq_init:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe.GuiderPipeline.dq_init:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe.GuiderPipeline.dq_init:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe.GuiderPipeline.dq_init:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# INFO     stpipe.GuiderPipeline.dq_init:dq_init_step.py:47 Input opened as GuiderRawModel
# INFO     stpipe.GuiderPipeline.dq_init:dq_init_step.py:63 Using MASK reference file /grp/crds/cache/references/jwst/jwst_fgs_mask_0025.fits
# DEBUG    stpipe.GuiderPipeline.dq_init:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe.GuiderPipeline.dq_init:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe.GuiderPipeline.dq_init:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe.GuiderPipeline.dq_init:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe.GuiderPipeline.dq_init:util.py:175 Environmental "SKIP_FITS_UPDATE" cannot be found. Using default value of "None".
# DEBUG    stpipe.GuiderPipeline.dq_init:util.py:175 Environmental "SKIP_FITS_UPDATE" cannot be found. Using default value of "None".
# DEBUG    stpipe.GuiderPipeline.dq_init:fits_support.py:675 No ASDF information found. Cannot skip updating from FITS headers.
# DEBUG    stpipe.GuiderPipeline.dq_init:fits_support.py:675 No ASDF information found. Cannot skip updating from FITS headers.
# WARNING  stpipe.GuiderPipeline.dq_init:dynamicdq.py:29 Keyword FGS_WARM does not correspond to an existing DQ mnemonic, so will be ignored
# WARNING  stpipe.GuiderPipeline.dq_init:dynamicdq.py:29 Keyword FGS_WARM does not correspond to an existing DQ mnemonic, so will be ignored
# WARNING  stpipe.GuiderPipeline.dq_init:dynamicdq.py:29 Keyword FGS_NOISY does not correspond to an existing DQ mnemonic, so will be ignored
# WARNING  stpipe.GuiderPipeline.dq_init:dynamicdq.py:29 Keyword FGS_NOISY does not correspond to an existing DQ mnemonic, so will be ignored
# DEBUG    stpipe.GuiderPipeline.dq_init:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe.GuiderPipeline.dq_init:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe.GuiderPipeline.dq_init:reffile_utils.py:114 ref substrt1=1, subsize1=2048, substrt2=1, subsize2=2048
# DEBUG    stpipe.GuiderPipeline.dq_init:reffile_utils.py:114 ref substrt1=1, subsize1=2048, substrt2=1, subsize2=2048
# DEBUG    stpipe.GuiderPipeline.dq_init:reffile_utils.py:167 sci substrt1=1000, subsize1=128, substrt2=1000, subsize2=128
# DEBUG    stpipe.GuiderPipeline.dq_init:reffile_utils.py:167 sci substrt1=1000, subsize1=128, substrt2=1000, subsize2=128
# INFO     stpipe.GuiderPipeline.dq_init:dq_initialization.py:66 Extracting mask subarray to match science data
# INFO     stpipe.GuiderPipeline.dq_init:dq_initialization.py:66 Extracting mask subarray to match science data
# DEBUG    stpipe.GuiderPipeline.dq_init:reffile_utils.py:336 slice xstart=999, xstop=1127, ystart=999, ystop=1127
# DEBUG    stpipe.GuiderPipeline.dq_init:reffile_utils.py:336 slice xstart=999, xstop=1127, ystart=999, ystop=1127
# DEBUG    stpipe.GuiderPipeline.dq_init:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe.GuiderPipeline.dq_init:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe.GuiderPipeline.dq_init:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe.GuiderPipeline.dq_init:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# INFO     stpipe.GuiderPipeline.dq_init:step.py:897 Saved model in exptype_fgs_acq1_dq_init.fits
# INFO     stpipe.GuiderPipeline.dq_init:step.py:474 Step dq_init done
# INFO     stpipe.GuiderPipeline.guider_cds:step.py:360 Step guider_cds running with args (<GuiderRawModel(6, 2, 128, 128) from exptype_fgs_acq1_dq_init.fits>,).
# INFO     stpipe.GuiderPipeline.guider_cds:step.py:364 Step guider_cds parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-0/test_fgs_guider_run_guider_pipelines0'}
# DEBUG    stpipe.GuiderPipeline.guider_cds:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe.GuiderPipeline.guider_cds:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe.GuiderPipeline.guider_cds:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe.GuiderPipeline.guider_cds:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# INFO     stpipe.GuiderPipeline.guider_cds:guider_cds.py:139 Instrument: FGS
# INFO     stpipe.GuiderPipeline.guider_cds:guider_cds.py:139 Instrument: FGS
# INFO     stpipe.GuiderPipeline.guider_cds:guider_cds.py:140 Exposure type: FGS_ACQ1
# INFO     stpipe.GuiderPipeline.guider_cds:guider_cds.py:140 Exposure type: FGS_ACQ1
# INFO     stpipe.GuiderPipeline.guider_cds:guider_cds.py:141 Number of integrations: 6
# INFO     stpipe.GuiderPipeline.guider_cds:guider_cds.py:141 Number of integrations: 6
# INFO     stpipe.GuiderPipeline.guider_cds:guider_cds.py:142 Number of groups per integration: 2
# INFO     stpipe.GuiderPipeline.guider_cds:guider_cds.py:142 Number of groups per integration: 2
# INFO     stpipe.GuiderPipeline.guider_cds:guider_cds.py:143 Group time: 0.3612000000000001
# INFO     stpipe.GuiderPipeline.guider_cds:guider_cds.py:143 Group time: 0.3612000000000001
# INFO     stpipe.GuiderPipeline.guider_cds:guider_cds.py:144 Frame time:    0.18060
# INFO     stpipe.GuiderPipeline.guider_cds:guider_cds.py:144 Frame time:    0.18060
# DEBUG    stpipe.GuiderPipeline.guider_cds:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe.GuiderPipeline.guider_cds:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe.GuiderPipeline.guider_cds:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe.GuiderPipeline.guider_cds:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# INFO     stpipe.GuiderPipeline.guider_cds:step.py:897 Saved model in exptype_fgs_acq1_guider_cds.fits
# INFO     stpipe.GuiderPipeline.guider_cds:step.py:474 Step guider_cds done
# INFO     stpipe.GuiderPipeline.flat_field:step.py:360 Step flat_field running with args (<GuiderCalModel(6, 128, 128) from exptype_fgs_acq1_guider_cds.fits>,).
# INFO     stpipe.GuiderPipeline.flat_field:step.py:364 Step flat_field parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-0/test_fgs_guider_run_guider_pipelines0', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}
# DEBUG    stpipe.GuiderPipeline.flat_field:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe.GuiderPipeline.flat_field:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe.GuiderPipeline.flat_field:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe.GuiderPipeline.flat_field:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe.GuiderPipeline.flat_field:flat_field_step.py:72 Input is GuiderCalModel of exposure type FGS_ACQ1
# DEBUG    stpipe.GuiderPipeline.flat_field:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe.GuiderPipeline.flat_field:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe.GuiderPipeline.flat_field:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe.GuiderPipeline.flat_field:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe.GuiderPipeline.flat_field:util.py:175 Environmental "SKIP_FITS_UPDATE" cannot be found. Using default value of "None".
# DEBUG    stpipe.GuiderPipeline.flat_field:util.py:175 Environmental "SKIP_FITS_UPDATE" cannot be found. Using default value of "None".
# DEBUG    stpipe.GuiderPipeline.flat_field:fits_support.py:675 No ASDF information found. Cannot skip updating from FITS headers.
# DEBUG    stpipe.GuiderPipeline.flat_field:fits_support.py:675 No ASDF information found. Cannot skip updating from FITS headers.
# DEBUG    stpipe.GuiderPipeline.flat_field:flat_field_step.py:197 Using FLAT reference file: /grp/crds/cache/references/jwst/jwst_fgs_flat_0010.fits
# DEBUG    stpipe.GuiderPipeline.flat_field:flat_field_step.py:199 No reference found for type FFLAT
# DEBUG    stpipe.GuiderPipeline.flat_field:flat_field_step.py:199 No reference found for type SFLAT
# DEBUG    stpipe.GuiderPipeline.flat_field:flat_field_step.py:199 No reference found for type DFLAT
# DEBUG    stpipe.GuiderPipeline.flat_field:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe.GuiderPipeline.flat_field:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe.GuiderPipeline.flat_field:flat_field.py:111 Flat field correction for non-NIRSpec modes.
# DEBUG    stpipe.GuiderPipeline.flat_field:flat_field.py:111 Flat field correction for non-NIRSpec modes.
# DEBUG    stpipe.GuiderPipeline.flat_field:reffile_utils.py:114 ref substrt1=1, subsize1=2048, substrt2=1, subsize2=2048
# DEBUG    stpipe.GuiderPipeline.flat_field:reffile_utils.py:114 ref substrt1=1, subsize1=2048, substrt2=1, subsize2=2048
# DEBUG    stpipe.GuiderPipeline.flat_field:reffile_utils.py:167 sci substrt1=1000, subsize1=128, substrt2=1000, subsize2=128
# DEBUG    stpipe.GuiderPipeline.flat_field:reffile_utils.py:167 sci substrt1=1000, subsize1=128, substrt2=1000, subsize2=128
# INFO     stpipe.GuiderPipeline.flat_field:flat_field.py:169 Extracting matching subarray from flat
# INFO     stpipe.GuiderPipeline.flat_field:flat_field.py:169 Extracting matching subarray from flat
# DEBUG    stpipe.GuiderPipeline.flat_field:reffile_utils.py:336 slice xstart=999, xstop=1127, ystart=999, ystop=1127
# DEBUG    stpipe.GuiderPipeline.flat_field:reffile_utils.py:336 slice xstart=999, xstop=1127, ystart=999, ystop=1127
# DEBUG    stpipe.GuiderPipeline.flat_field:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe.GuiderPipeline.flat_field:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe.GuiderPipeline.flat_field:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe.GuiderPipeline.flat_field:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# INFO     stpipe.GuiderPipeline.flat_field:step.py:474 Step flat_field done
# INFO     stpipe.GuiderPipeline:calwebb_guider.py:57 ... ending calwebb_guider
# INFO     stpipe.GuiderPipeline:calwebb_guider.py:57 ... ending calwebb_guider
# INFO     stpipe.GuiderPipeline:step.py:897 Saved model in exptype_fgs_acq1_cal.fits
# INFO     stpipe.GuiderPipeline:step.py:474 Step GuiderPipeline done
# ------------------------------ Captured log call -------------------------------
# DEBUG    stpipe:connectionpool.py:971 Starting new HTTPS connection (1): bytesalad.stsci.edu:443
# DEBUG    stpipe:connectionpool.py:971 Starting new HTTPS connection (1): bytesalad.stsci.edu:443
# DEBUG    stpipe:connectionpool.py:452 https://bytesalad.stsci.edu:443 "GET /artifactory HTTP/1.1" 302 0
# DEBUG    stpipe:connectionpool.py:452 https://bytesalad.stsci.edu:443 "GET /artifactory HTTP/1.1" 302 0
# DEBUG    stpipe:connectionpool.py:452 https://bytesalad.stsci.edu:443 "GET /artifactory/ HTTP/1.1" 302 0
# DEBUG    stpipe:connectionpool.py:452 https://bytesalad.stsci.edu:443 "GET /artifactory/ HTTP/1.1" 302 0
# DEBUG    stpipe:connectionpool.py:452 https://bytesalad.stsci.edu:443 "GET /ui/ HTTP/1.1" 200 1196
# DEBUG    stpipe:connectionpool.py:452 https://bytesalad.stsci.edu:443 "GET /ui/ HTTP/1.1" 200 1196
# DEBUG    stpipe:connectionpool.py:971 Starting new HTTPS connection (1): bytesalad.stsci.edu:443
# DEBUG    stpipe:connectionpool.py:971 Starting new HTTPS connection (1): bytesalad.stsci.edu:443
# DEBUG    stpipe:connectionpool.py:452 https://bytesalad.stsci.edu:443 "GET /artifactory/jwst-pipeline/dev/truth/fgs/test_fgs_guider/exptype_fgs_acq1_cal.fits HTTP/1.1" 200 1284480
# DEBUG    stpipe:connectionpool.py:452 https://bytesalad.stsci.edu:443 "GET /artifactory/jwst-pipeline/dev/truth/fgs/test_fgs_guider/exptype_fgs_acq1_cal.fits HTTP/1.1" 200 1284480
# DEBUG    stpipe:connectionpool.py:971 Starting new HTTPS connection (1): bytesalad.stsci.edu:443
# DEBUG    stpipe:connectionpool.py:971 Starting new HTTPS connection (1): bytesalad.stsci.edu:443
# DEBUG    stpipe:connectionpool.py:452 https://bytesalad.stsci.edu:443 "GET /artifactory/jwst-pipeline/dev/truth/fgs/test_fgs_guider/exptype_fgs_acq1_cal.fits HTTP/1.1" 200 1284480
# DEBUG    stpipe:connectionpool.py:452 https://bytesalad.stsci.edu:443 "GET /artifactory/jwst-pipeline/dev/truth/fgs/test_fgs_guider/exptype_fgs_acq1_cal.fits HTTP/1.1" 200 1284480
# __________________ test_fgs_guider[exptype_fgs_acq1-dq_init] ___________________
#
# run_guider_pipelines = {'input': '/data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-0/tes...e_fgs_acq1_dq_init.fits',
#  'truth_remote': 'jwst-pipeline/dev/truth/fgs/test_fgs_guider/exptype_fgs_acq1_dq_init.fits'}
# fitsdiff_default_kwargs = {'atol': 1e-07, 'ignore_fields': ['DATE', 'CAL_VER', 'CAL_VCS', 'CRDS_VER', 'CRDS_CTX', 'NAXIS1', ...], 'ignore_hdus': ['ASDF'], 'ignore_keywords': ['DATE', 'CAL_VER', 'CAL_VCS', 'CRDS_VER', 'CRDS_CTX', 'NAXIS1', ...], ...}
# suffix = 'dq_init'
#
#     @pytest.mark.bigdata
#     @pytest.mark.parametrize('suffix', guider_suffixes, ids=guider_suffixes)
#     def test_fgs_guider(run_guider_pipelines, fitsdiff_default_kwargs, suffix):
#         """Regression for FGS Guider data"""
# >       rt.is_like_truth(run_guider_pipelines, fitsdiff_default_kwargs, suffix,
#                          'truth/fgs/test_fgs_guider', is_suffix=True)
# E       AssertionError:
# E        fitsdiff: 4.2
# E        a: /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-0/test_fgs_guider_run_guider_pipelines0/exptype_fgs_acq1_dq_init.fits
# E        b: /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-0/test_fgs_guider_run_guider_pipelines0/truth/exptype_fgs_acq1_dq_init.fits
# E        HDU(s) not to be compared:
# E         ASDF
# E        Keyword(s) not to be compared:
# E         CAL_VCS CAL_VER CRDS_CTX CRDS_VER DATE NAXIS1 TFORM*
# E        Table column(s) not to be compared:
# E         CAL_VCS CAL_VER CRDS_CTX CRDS_VER DATE NAXIS1 TFORM*
# E        Maximum number of different data values to be reported: 10
# ...
# =============================== warnings summary ===============================
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_guider[exptype_fgs_acq1-cal]
#   /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/datamodels/util.py:202: NoTypeWarning: model_type not found. Opening /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-0/test_fgs_guider_run_guider_pipelines0/exptype_fgs_acq1_uncal.fits as a RampModel
#     warnings.warn(f"model_type not found. Opening {file_name} as a {class_name}",
#
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_guider[exptype_fgs_acq1-cal]
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_guider[exptype_fgs_fineguide-cal]
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_guider[exptype_fgs_id_image-cal]
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_guider[exptype_fgs_id_stack-cal]
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_image2.py::test_fgs_image2[jw86500007001_02101_00001_GUIDER2_cal.fits]
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_image2.py::test_fgs_image2[jw86500007001_02101_00001_GUIDER2_flat_field.fits]
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_image2.py::test_fgs_image2[jw86500007001_02101_00001_GUIDER2_i2d.fits]
#   /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/flatfield/flat_field.py:221: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
#   Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#     flag_nonsci = np.bitwise_and(science.dq, dqflags.pixel['NON_SCIENCE']).astype(np.bool)
#
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_guider[exptype_fgs_fineguide-cal]
#   /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/datamodels/util.py:202: NoTypeWarning: model_type not found. Opening /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-0/test_fgs_guider_run_guider_pipelines0/exptype_fgs_fineguide_uncal.fits as a RampModel
#     warnings.warn(f"model_type not found. Opening {file_name} as a {class_name}",
#
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_guider[exptype_fgs_id_image-cal]
#   /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/datamodels/util.py:202: NoTypeWarning: model_type not found. Opening /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-0/test_fgs_guider_run_guider_pipelines0/exptype_fgs_id_image_uncal.fits as a RampModel
#     warnings.warn(f"model_type not found. Opening {file_name} as a {class_name}",
#
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_toobig
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_toobig
#   /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/tweakreg/tweakreg_catalog.py:76: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
#   Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#     mask = (dqflags.pixel['NON_SCIENCE'] & model.dq).astype(np.bool)
#
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_toobig
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_toobig
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_toobig
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_toobig
#   /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/gwcs/wcs.py:1990: DeprecationWarning: Indexing a WCS.pipeline step is deprecated. Use the `frame` and `transform` attributes instead.
#     warnings.warn("Indexing a WCS.pipeline step is deprecated. "
#
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_toobig
#   /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/tweakwcs/linalg.py:111: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
#   Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#     qt = np.eye(order, dtype=np.int)
#
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_toobig
#   /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/tweakwcs/linalg.py:134: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
#   Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#     q = np.eye(order, dtype=np.int)
#
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_toobig
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_toobig
#   /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/skymatch/skyimage.py:125: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
#   Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#     self.mask = np.asanyarray(mask, dtype=np.bool)
#
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_toobig
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_toobig
#   /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/skymatch/skyimage.py:257: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
#   Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#     xs = np.linspace(-0.5, nx - 0.5, nintx, dtype=np.float)
#
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_toobig
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_toobig
#   /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/skymatch/skyimage.py:258: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
#   Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#     ys = np.linspace(-0.5, ny - 0.5, ninty, dtype=np.float)[1:-1]
#
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_toobig
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_toobig
#   /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/skymatch/skyimage.py:264: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
#   Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#     borderx = np.empty((npts + 1,), dtype=np.float)
#
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_toobig
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_toobig
#   /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/skymatch/skyimage.py:265: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
#   Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#     bordery = np.empty((npts + 1,), dtype=np.float)
#
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_image2.py::test_fgs_image2[jw86500007001_02101_00001_GUIDER2_cal.fits]
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_image2.py::test_fgs_image2[jw86500007001_02101_00001_GUIDER2_cal.fits]
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_image2.py::test_fgs_image2[jw86500007001_02101_00001_GUIDER2_flat_field.fits]
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_image2.py::test_fgs_image2[jw86500007001_02101_00001_GUIDER2_flat_field.fits]
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_image2.py::test_fgs_image2[jw86500007001_02101_00001_GUIDER2_i2d.fits]
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_image2.py::test_fgs_image2[jw86500007001_02101_00001_GUIDER2_i2d.fits]
#   /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/gwcs/utils.py:72: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
#   Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#     indx = np.asarray(np.floor(np.asarray(value) + 0.5), dtype=np.int)
#
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_image2.py::test_fgs_image2[jw86500007001_02101_00001_GUIDER2_cal.fits]
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_image2.py::test_fgs_image2[jw86500007001_02101_00001_GUIDER2_flat_field.fits]
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_image2.py::test_fgs_image2[jw86500007001_02101_00001_GUIDER2_i2d.fits]
#   /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/datamodels/util.py:202: NoTypeWarning: model_type not found. Opening /grp/crds/cache/references/jwst/jwst_fgs_area_0012.fits as a ReferenceImageModel
#     warnings.warn(f"model_type not found. Opening {file_name} as a {class_name}",
#
# -- Docs: https://docs.pytest.org/en/stable/warnings.html
# - generated html file: file:///data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/jwst_validation_notebooks/regression_test/tmpdir/regtest_report.html -
# =========================== short test summary info ============================
# FAILED ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_guider[exptype_fgs_acq1-cal]
# FAILED ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_guider[exptype_fgs_acq1-dq_init]
# FAILED ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_guider[exptype_fgs_acq1-guider_cds]
# FAILED ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_guider[exptype_fgs_id_image-cal]
# FAILED ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_guider[exptype_fgs_id_image-dq_init]
# FAILED ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_guider[exptype_fgs_id_image-guider_cds]
# FAILED ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_guider[exptype_fgs_id_stack-cal]
# FAILED ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_guider[exptype_fgs_id_stack-dq_init]
# FAILED ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_guider.py::test_fgs_guider[exptype_fgs_id_stack-guider_cds]
# FAILED ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_fgs_image2.py::test_fgs_image2[jw86500007001_02101_00001_GUIDER2_i2d.fits]
# ===== 10 failed, 6 passed, 431 deselected, 37 warnings in 64.12s (0:01:04) =====

# %%
report
# Out:
#         <iframe
#             width="700"
#             height="600"
#             src="tmpdir/regtest_report.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# <a id="about"></a>
# ## About This Notebook
# **Author:** Alicia Canipe, Staff Scientist, NIRCam
# <br>**Updated On:** 01/27/2021

# %% [markdown]
# [Top of Page](#title_ID)
# <img style="float: right;" src="./stsci_pri_combo_mark_horizonal_white_bkgd.png" alt="stsci_pri_combo_mark_horizonal_white_bkgd" width="200px"/>
