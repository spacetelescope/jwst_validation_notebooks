# %% [markdown]
# <a id="title_ID"></a>
# # JWST MIRI regression tests
#
# <span style="color:red"> **Instruments Affected**</span>: MIRI
# ### Table of Contents
#
# <div style="text-align: left">
#
# <br> [Introduction](#intro)
# <br> [JWST Regression Tests](#unit)
# <br> [Defining Terms](#terms)
# <br> [Test Description](#description)
# <br> [Data Description](#data_descr)
# <br> [Imports](#imports)
# <br> [Convenience Functions](#functions)
# <br> [Perform Tests](#testing)
# <br> [About This Notebook](#about)
# <br>
#
# </div>

# %% [markdown]
# <a id="intro"></a>
# # Introduction
#
# This is the validation notebook that displays the regression tests for the MIRI instrument in the JWST calibration pipeline. This notebook runs and displays the regression tests that are performed as a part of the normal software continuous integration process. For more information on the pipeline visit the links below.
#
# * Pipeline description: https://jwst-pipeline.readthedocs.io/en/latest/index.html
#
# * Pipeline code: https://github.com/spacetelescope/jwst
#
# [Top of Page](#title_ID)

# %% [markdown]
# <a id="unit"></a>
# # JWST Regression Tests
#
# JWST regression tests are located in the ```regtest``` folder of the pipeline within the [GitHub repository](https://github.com/spacetelescope/jwst/tree/master/jwst/regtest).
#
# * Regression test README: https://github.com/spacetelescope/jwst#regression-tests
#
#
# [Top of Page](#title_ID)

# %% [markdown]
# <a id="terms"></a>
# # Defining Terms
#
# These are terms or acronymns used in this notebook that may not be known a general audience.
#
# * JWST: James Webb Space Telescope
#
# * MIRI: Near-Infrared Camera
#
#
# [Top of Page](#title_ID)

# %% [markdown]
# <a id="description"></a>
# # Test Description
#
# Regression testing is a software testing method which checks if the pipeline step produces the expected outcome by comparing an input file with a truth file. Truth files for testing are stored in Artifactory.
#
#
# [Top of Page](#title_ID)

# %% [markdown]
# <a id="data_descr"></a>
# # Data Description
#
# Data used for regression tests is stored in Artifactory, and consists of a mix of simulated and ground testing data for the different instruments and modes.
#
#
# [Top of Page](#title_ID)

# %% [markdown]
# <a id="imports"></a>
# # Imports
#
# * tempfile for creating temporary output products
# * pytest for unit test functions
# * jwst for the JWST Pipeline
# * IPython.display for display pytest reports
#
# [Top of Page](#title_ID)

# %%
import tempfile
import os
import pytest
import jwst
from IPython.display import IFrame

# %% [markdown]
# <a id="functions"></a>
# # Convenience Functions
#
# Here we define any convenience functions to help with running the unit tests.
#
# [Top of Page](#title_ID)

# %%
def display_report(fname):
    '''Convenience function to display pytest report.'''
    
    return IFrame(src=fname, width=700, height=600)

# %% [markdown]
# <a id="testing"></a>
# # Perform Tests
#
# Below we run the regression tests for the MIRI instrument.
#
# [Top of Page](#title_ID)

# %%
jwst_dir = os.path.dirname(jwst.__file__)
regtest = os.path.join(jwst_dir, 'regtest')
associations = os.path.join(jwst_dir, 'associations')
datamodels = os.path.join(jwst_dir, 'datamodels')
stpipe = os.path.join(jwst_dir, 'stpipe')

with tempfile.TemporaryDirectory() as tmpdir:
    # !pytest --bigdata {regtest} -k 'test_miri' -v --ignore={associations} --ignore={datamodels} --ignore={stpipe} --html=tmpdir/regtest_report.html --self-contained-html
    report = display_report('tmpdir/regtest_report.html')
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.9.1, pytest-6.2.2, py-1.10.0, pluggy-0.13.1 -- /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/miniconda3/envs/jwst_validation_notebooks/bin/python
# cachedir: .pytest_cache
# metadata: {'Python': '3.9.1', 'Platform': 'Linux-3.10.0-1160.11.1.el7.x86_64-x86_64-with-glibc2.17', 'Packages': {'pytest': '6.2.2', 'py': '1.10.0', 'pluggy': '0.13.1'}, 'Plugins': {'metadata': '1.11.0', 'asdf': '2.7.2', 'html': '3.1.1', 'forked': '1.3.0', 'xdist': '2.2.0', 'ci-watson': '0.5'}, 'BUILD_NUMBER': '52', 'BUILD_ID': '52', 'BUILD_URL': 'https://plwishmaster.stsci.edu:8081/job/Notebooks/job/jwst_validation_notebooks_spacetelescope/52/', 'NODE_NAME': 'jwcalibdev.stsci.edu', 'JOB_NAME': 'Notebooks/jwst_validation_notebooks_spacetelescope', 'BUILD_TAG': 'jenkins-Notebooks-jwst_validation_notebooks_spacetelescope-52', 'EXECUTOR_NUMBER': '29', 'JENKINS_URL': 'https://plwishmaster.stsci.edu:8081/', 'WORKSPACE': '/data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope', 'GIT_COMMIT': 'f6ea8bc553cb5ba6998fd20927d8e020dec1e853', 'GIT_URL': 'https://github.com/spacetelescope/jwst_validation_notebooks', 'GIT_BRANCH': 'origin/master'}
# rootdir: /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope
# plugins: metadata-1.11.0, asdf-2.7.2, html-3.1.1, forked-1.3.0, xdist-2.2.0, ci-watson-0.5
# collecting ...
# collecting 311 items
# collected 447 items / 357 deselected / 90 selected
#
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_cubebuild.py::test_cube_build_single_output[outtest_ch1-short_s3d.fits] SKIPPED [  1%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_cubebuild.py::test_cube_build_single_output[outtest_ch2-short_s3d.fits] SKIPPED [  2%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_dark.py::test_miri_dark_pipeline
# FAILED [  3%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_image.py::test_miri_image_detector1[dq_init]
# PASSED [  4%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_image.py::test_miri_image_detector1[saturation]
# PASSED [  5%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_image.py::test_miri_image_detector1[refpix]
# PASSED [  6%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_image.py::test_miri_image_detector1[rscd]
# PASSED [  7%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_image.py::test_miri_image_detector1[firstframe]
# PASSED [  8%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_image.py::test_miri_image_detector1[lastframe]
# PASSED [ 10%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_image.py::test_miri_image_detector1[reset]
# PASSED [ 11%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_image.py::test_miri_image_detector1[linearity]
# PASSED [ 12%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_image.py::test_miri_image_detector1[dark_current]
# PASSED [ 13%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_image.py::test_miri_image_detector1[ramp]
# PASSED [ 14%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_image.py::test_miri_image_detector1[rate]
# PASSED [ 15%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_image.py::test_miri_image_detector1[rateints]
# PASSED [ 16%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_image.py::test_miri_image_image2[assign_wcs]
# PASSED [ 17%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_image.py::test_miri_image_image2[flat_field]
# PASSED [ 18%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_image.py::test_miri_image_image2[cal]
# PASSED [ 20%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_image.py::test_miri_image_image2[i2d]
# PASSED [ 21%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_image.py::test_miri_image_image3[a3001_crf]
# PASSED [ 22%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_image.py::test_miri_image3_i2d
# FAILED [ 23%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_image.py::test_miri_image3_catalog
# PASSED [ 24%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_image.py::test_miri_image_wcs
# PASSED [ 25%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_dedicated_mbkg.py::test_miri_lrs_dedicated_mbkg
# PASSED [ 26%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_masterbg_user.py::test_miri_lrs_masterbg_user
# FAILED [ 27%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_nod_masterbg.py::test_miri_lrs_nod_masterbg[seq1]
# PASSED [ 28%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_nod_masterbg.py::test_miri_lrs_nod_masterbg[seq2]
# PASSED [ 30%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slit_spec2.py::test_miri_lrs_slit_spec2[bsub]
# FAILED [ 31%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slit_spec2.py::test_miri_lrs_slit_spec2[flat_field]
# FAILED [ 32%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slit_spec2.py::test_miri_lrs_slit_spec2[assign_wcs]
# FAILED [ 33%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slit_spec2.py::test_miri_lrs_slit_spec2[srctype]
# FAILED [ 34%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slit_spec2.py::test_miri_lrs_slit_spec2[cal]
# FAILED [ 35%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slit_spec2.py::test_miri_lrs_slit_spec2[x1d]
# FAILED [ 36%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slit_spec2.py::test_miri_lrs_slit_wcs
# PASSED [ 37%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slit_spec3.py::test_miri_lrs_slit_spec3[s2d]
# FAILED [ 38%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slit_spec3.py::test_miri_lrs_slit_spec3[x1d]
# FAILED [ 40%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slitless.py::test_miri_lrs_slitless_tso1[dq_init]
# FAILED [ 41%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slitless.py::test_miri_lrs_slitless_tso1[saturation]
# FAILED [ 42%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slitless.py::test_miri_lrs_slitless_tso1[refpix]
# FAILED [ 43%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slitless.py::test_miri_lrs_slitless_tso1[linearity]
# FAILED [ 44%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slitless.py::test_miri_lrs_slitless_tso1[dark_current]
# FAILED [ 45%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slitless.py::test_miri_lrs_slitless_tso1[jump]
# FAILED [ 46%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slitless.py::test_miri_lrs_slitless_tso1[rate]
# FAILED [ 47%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slitless.py::test_miri_lrs_slitless_tso1[rateints]
# FAILED [ 48%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slitless.py::test_miri_lrs_slitless_tso_spec2[flat_field]
# FAILED [ 50%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slitless.py::test_miri_lrs_slitless_tso_spec2[srctype]
# FAILED [ 51%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slitless.py::test_miri_lrs_slitless_tso_spec2[calints]
# FAILED [ 52%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slitless.py::test_miri_lrs_slitless_tso_spec2[assign_wcs]
# FAILED [ 53%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slitless.py::test_miri_lrs_slitless_tso_spec2[x1dints]
# FAILED [ 54%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slitless.py::test_miri_lrs_slitless_tso3[outlier_detection]
# FAILED [ 55%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slitless.py::test_miri_lrs_slitless_tso3[crfints]
# FAILED [ 56%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slitless.py::test_miri_lrs_slitless_tso3_x1dints
# FAILED [ 57%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slitless.py::test_miri_lrs_slitless_tso3_whtlt
# PASSED [ 58%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slitless.py::test_miri_lrs_slitless_wcs
# PASSED [ 60%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_dedicated_mbkg.py::test_miri_mrs_dedicated_mbkg[exp1]
# PASSED [ 61%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_dedicated_mbkg.py::test_miri_mrs_dedicated_mbkg[exp2]
# PASSED [ 62%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_dedicated_mbkg.py::test_miri_mrs_dedicated_mbkg[exp3]
# PASSED [ 63%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_extract1d.py::test_miri_mrs_extract1d
# PASSED [ 64%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_nod_masterbg.py::test_miri_mrs_nod_masterbg[seq1]
# PASSED [ 65%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_nod_masterbg.py::test_miri_mrs_nod_masterbg[seq2]
# PASSED [ 66%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_spec2.py::test_spec2[assign_wcs] SKIPPED [ 67%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_spec2.py::test_spec2[cal] SKIPPED [ 68%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_spec2.py::test_spec2[flat_field] SKIPPED [ 70%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_spec2.py::test_spec2[fringe] SKIPPED [ 71%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_spec2.py::test_spec2[photom] SKIPPED [ 72%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_spec2.py::test_spec2[s3d] SKIPPED [ 73%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_spec2.py::test_spec2[srctype] SKIPPED [ 74%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_spec2.py::test_spec2[straylight] SKIPPED [ 75%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_spec2.py::test_spec2[x1d] SKIPPED [ 76%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_spec2.py::test_miri_mrs_wcs SKIPPED [ 77%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_spec3.py::test_spec3[mrs_imatch] SKIPPED [ 78%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_spec3.py::test_spec3[ch1-s3d] SKIPPED [ 80%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_spec3.py::test_spec3[ch2-s3d] SKIPPED [ 81%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_spec3.py::test_spec3[ch1-x1d] SKIPPED [ 82%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_spec3.py::test_spec3[ch2-x1d] SKIPPED [ 83%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_spec3.py::test_spec3_multi[ch1-mrs_imatch] SKIPPED [ 84%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_spec3.py::test_spec3_multi[ch2-mrs_imatch] SKIPPED [ 85%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_spec3.py::test_spec3_multi[ch1-crf] SKIPPED [ 86%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_spec3.py::test_spec3_multi[ch2-crf] SKIPPED [ 87%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_spec3.py::test_spec3_multi[ch1-s3d] SKIPPED [ 88%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_spec3.py::test_spec3_multi[ch2-s3d] SKIPPED [ 90%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_spec3.py::test_spec3_multi[ch1-x1d] SKIPPED [ 91%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_spec3.py::test_spec3_multi[ch2-x1d] SKIPPED [ 92%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_tso.py::test_spec2[assign_wcs]
# FAILED [ 93%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_tso.py::test_spec2[calints]
# FAILED [ 94%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_tso.py::test_spec2[flat_field]
# FAILED [ 95%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_tso.py::test_spec2[fringe]
# FAILED [ 96%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_tso.py::test_spec2[photom]
# FAILED [ 97%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_tso.py::test_spec2[srctype]
# FAILED [ 98%]
# ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_setpointing.py::test_miri_setpointing
# FAILED [100%]
# =================================== FAILURES ===================================
# ___________________________ test_miri_dark_pipeline ____________________________
#
# _jail = '/data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-1/test_miri_dark_pipeline0'
# rtdata = {'input': '/data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-1/tes...fits',
#  'truth_remote': 'jwst-pipeline/dev/truth/test_miri_dark_pipeline/jw00001001001_01101_00001_mirimage_dark.fits'}
# fitsdiff_default_kwargs = {'atol': 1e-07, 'ignore_fields': ['DATE', 'CAL_VER', 'CAL_VCS', 'CRDS_VER', 'CRDS_CTX', 'NAXIS1', ...], 'ignore_hdus': ['ASDF'], 'ignore_keywords': ['DATE', 'CAL_VER', 'CAL_VCS', 'CRDS_VER', 'CRDS_CTX', 'NAXIS1', ...], ...}
#     @pytest.mark.bigdata
#     def test_miri_dark_pipeline(_jail, rtdata, fitsdiff_default_kwargs):
#         rtdata.get_data("miri/image/jw00001001001_01101_00001_mirimage_uncal.fits")
#
#         collect_pipeline_cfgs("config")
#         args = ["config/calwebb_dark.cfg", rtdata.input]
#         Step.from_cmdline(args)
#         rtdata.output = "jw00001001001_01101_00001_mirimage_dark.fits"
#
#         rtdata.get_truth("truth/test_miri_dark_pipeline/jw00001001001_01101_00001_mirimage_dark.fits")
#
#         diff = FITSDiff(rtdata.output, rtdata.truth, **fitsdiff_default_kwargs)
# >       assert diff.identical, diff.report()
# E       AssertionError:
# E          fitsdiff: 4.2
# E          a: /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-1/test_miri_dark_pipeline0/jw00001001001_01101_00001_mirimage_dark.fits
# E          b: /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-1/test_miri_dark_pipeline0/truth/jw00001001001_01101_00001_mirimage_dark.fits
# E          HDU(s) not to be compared:
# E           ASDF
# E          Keyword(s) not to be compared:
# E           CAL_VCS CAL_VER CRDS_CTX CRDS_VER DATE NAXIS1 TFORM*
# E          Table column(s) not to be compared:
# E           CAL_VCS CAL_VER CRDS_CTX CRDS_VER DATE NAXIS1 TFORM*
# E          Maximum number of different data values to be reported: 10
# E          Relative tolerance: 1e-05, Absolute tolerance: 1e-07
# E
# E         Primary HDU:
# E
# E            Headers contain differences:
# E              Headers have different number of cards:
# E               a: 146
# E               b: 145
# E              Inconsistent duplicates of keyword ''      :
# E               Occurs 20 time(s) in a, 19 times in (b)
# E              Keyword         [11] has different values:
# E                 a> Velocity aberration correction information
# E                 b> Time information
# E              Keyword         [12] has different values:
# E                 a> Time information
# E                 b> Guide star information
# E              Keyword         [13] has different values:
# E                 a> Guide star information
# E                 b> Reference file information
# E              Keyword         [14] has different values:
# E                 a> Reference file information
# E                 b> CRDS parameters
# E              Keyword         [15] has different values:
# E                 a> CRDS parameters
# E                 b> Linearity reference file information
# E              Keyword         [16] has different values:
# E                 a> Linearity reference file information
# E                  ? ^^^^ ^^^^
# E                 b> Mask reference file information
# E                  ? ^ ^^
# E              Keyword         [17] has different values:
# E                 a> Mask reference file information
# E                  ? ^^^^
# E                 b> RSCD reference file information
# E                  ? ^^^^
# E              Keyword         [18] has different values:
# E                 a> RSCD reference file information
# E                  ? - ^^
# E                 b> Saturation reference file information
# E                  ?  ^^^^^^^^^
# E              Keyword         [19] has different values:
# E                 a> Saturation reference file information
# E                 b> Calibration step information
# E
# E         Extension HDU 1 (SCI, 1):
# E
# E            Headers contain differences:
# E              Headers have different number of cards:
# E               a: 37
# E               b: 38
# E              Inconsistent duplicates of keyword ''      :
# E               Occurs 3 time(s) in a, 4 times in (b)
# E              Keyword          has different values:
# E                 a> Information about the coordinates in the file
# E                 b> Velocity aberration correction information
# E              Keyword         [2] has different values:
# E                 a> Spacecraft pointing information
# E                 b> Information about the coordinates in the file
# E              Keyword         [3] has different values:
# E                 a> WCS parameters
# E                 b> Spacecraft pointing information
# E
# E       assert False
# E        +  where False = <astropy.io.fits.diff.FITSDiff object at 0x7f274aed5e50>.identical
#
# /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_dark.py:20: AssertionError
# ------------------------------ Captured log setup ------------------------------
# DEBUG    stpipe:connectionpool.py:971 Starting new HTTPS connection (1): bytesalad.stsci.edu:443
# DEBUG    stpipe:connectionpool.py:971 Starting new HTTPS connection (1): bytesalad.stsci.edu:443
# DEBUG    stpipe:connectionpool.py:452 https://bytesalad.stsci.edu:443 "GET /artifactory HTTP/1.1" 302 0
# DEBUG    stpipe:connectionpool.py:452 https://bytesalad.stsci.edu:443 "GET /artifactory HTTP/1.1" 302 0
# DEBUG    stpipe:connectionpool.py:452 https://bytesalad.stsci.edu:443 "GET /artifactory/ HTTP/1.1" 302 0
# DEBUG    stpipe:connectionpool.py:452 https://bytesalad.stsci.edu:443 "GET /artifactory/ HTTP/1.1" 302 0
# DEBUG    stpipe:connectionpool.py:452 https://bytesalad.stsci.edu:443 "GET /ui/ HTTP/1.1" 200 1196
# DEBUG    stpipe:connectionpool.py:452 https://bytesalad.stsci.edu:443 "GET /ui/ HTTP/1.1" 200 1196
# ----------------------------- Captured stderr call -----------------------------
# 2021-01-31 20:36:53,541 - stpipe.DarkPipeline - INFO - DarkPipeline instance created.
# 2021-01-31 20:36:53,542 - stpipe.DarkPipeline.group_scale - INFO - GroupScaleStep instance created.
# 2021-01-31 20:36:53,543 - stpipe.DarkPipeline.dq_init - INFO - DQInitStep instance created.
# 2021-01-31 20:36:53,543 - stpipe.DarkPipeline.saturation - INFO - SaturationStep instance created.
# 2021-01-31 20:36:53,544 - stpipe.DarkPipeline.ipc - INFO - IPCStep instance created.
# 2021-01-31 20:36:53,544 - stpipe.DarkPipeline.superbias - INFO - SuperBiasStep instance created.
# 2021-01-31 20:36:53,545 - stpipe.DarkPipeline.refpix - INFO - RefPixStep instance created.
# 2021-01-31 20:36:53,546 - stpipe.DarkPipeline.rscd - INFO - RscdStep instance created.
# 2021-01-31 20:36:53,546 - stpipe.DarkPipeline.firstframe - INFO - FirstFrameStep instance created.
# 2021-01-31 20:36:53,547 - stpipe.DarkPipeline.lastframe - INFO - LastFrameStep instance created.
# 2021-01-31 20:36:53,547 - stpipe.DarkPipeline.linearity - INFO - LinearityStep instance created.
# 2021-01-31 20:36:53,547 - stpipe - INFO - Hostname: jwcalibdev.stsci.edu
# 2021-01-31 20:36:53,548 - stpipe - INFO - OS: Linux
# 2021-01-31 20:36:53,707 - stpipe.DarkPipeline - INFO - Step DarkPipeline running with args ('/data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-1/test_miri_dark_pipeline0/jw00001001001_01101_00001_mirimage_uncal.fits',).
# 2021-01-31 20:36:53,712 - stpipe.DarkPipeline - INFO - Step DarkPipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'dark', 'search_output_file': True, 'input_dir': '/data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-1/test_miri_dark_pipeline0', 'steps': {'group_scale': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-1/test_miri_dark_pipeline0'}, 'dq_init': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-1/test_miri_dark_pipeline0'}, 'saturation': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-1/test_miri_dark_pipeline0'}, 'ipc': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '/data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-1/test_miri_dark_pipeline0'}, 'superbias': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-1/test_miri_dark_pipeline0'}, 'refpix': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-1/test_miri_dark_pipeline0', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}, 'rscd': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-1/test_miri_dark_pipeline0', 'type': 'baseline'}, 'firstframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-1/test_miri_dark_pipeline0'}, 'lastframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_f ...
# 2021-01-31 20:36:54,387 - stpipe.DarkPipeline - INFO - Prefetching reference files for dataset: 'jw00001001001_01101_00001_mirimage_uncal.fits' reftypes = ['linearity', 'mask', 'refpix', 'rscd', 'saturation', 'superbias']
# 2021-01-31 20:36:54,393 - stpipe.DarkPipeline - INFO - Prefetch for LINEARITY reference file is '/grp/crds/cache/references/jwst/jwst_miri_linearity_0024.fits'.
# 2021-01-31 20:36:54,394 - stpipe.DarkPipeline - INFO - Prefetch for MASK reference file is '/grp/crds/cache/references/jwst/jwst_miri_mask_0023.fits'.
# 2021-01-31 20:36:54,395 - stpipe.DarkPipeline - INFO - Prefetch for REFPIX reference file is 'N/A'.
# 2021-01-31 20:36:54,395 - stpipe.DarkPipeline - INFO - Prefetch for RSCD reference file is '/grp/crds/cache/references/jwst/jwst_miri_rscd_0010.fits'.
# 2021-01-31 20:36:54,395 - stpipe.DarkPipeline - INFO - Prefetch for SATURATION reference file is '/grp/crds/cache/references/jwst/jwst_miri_saturation_0026.fits'.
# 2021-01-31 20:36:54,396 - stpipe.DarkPipeline - INFO - Prefetch for SUPERBIAS reference file is 'N/A'.
# 2021-01-31 20:36:54,397 - stpipe.DarkPipeline - INFO - Starting calwebb_dark ...
# 2021-01-31 20:36:55,324 - stpipe.DarkPipeline.group_scale - INFO - Step group_scale running with args (<RampModel(3, 50, 1024, 1032) from jw00001001001_01101_00001_mirimage_uncal.fits>,).
# 2021-01-31 20:36:55,325 - stpipe.DarkPipeline.group_scale - INFO - Step group_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-1/test_miri_dark_pipeline0'}
# 2021-01-31 20:36:55,332 - stpipe.DarkPipeline.group_scale - INFO - NFRAMES=1 is a power of 2; correction not needed
# 2021-01-31 20:36:55,333 - stpipe.DarkPipeline.group_scale - INFO - Step will be skipped
# 2021-01-31 20:36:55,333 - stpipe.DarkPipeline.group_scale - INFO - Step group_scale done
# 2021-01-31 20:36:55,406 - stpipe.DarkPipeline.dq_init - INFO - Step dq_init running with args (<RampModel(3, 50, 1024, 1032) from jw00001001001_01101_00001_mirimage_uncal.fits>,).
# 2021-01-31 20:36:55,407 - stpipe.DarkPipeline.dq_init - INFO - Step dq_init parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-1/test_miri_dark_pipeline0'}
# 2021-01-31 20:36:55,415 - stpipe.DarkPipeline.dq_init - INFO - Using MASK reference file /grp/crds/cache/references/jwst/jwst_miri_mask_0023.fits
# 2021-01-31 20:36:56,377 - stpipe.DarkPipeline.dq_init - INFO - Step dq_init done
# 2021-01-31 20:36:56,525 - stpipe.DarkPipeline.saturation - INFO - Step saturation running with args (<RampModel(3, 50, 1024, 1032) from jw00001001001_01101_00001_mirimage_uncal.fits>,).
# 2021-01-31 20:36:56,526 - stpipe.DarkPipeline.saturation - INFO - Step saturation parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-1/test_miri_dark_pipeline0'}
# 2021-01-31 20:36:56,535 - stpipe.DarkPipeline.saturation - INFO - Using SATURATION reference file /grp/crds/cache/references/jwst/jwst_miri_saturation_0026.fits
# 2021-01-31 20:36:59,066 - stpipe.DarkPipeline.saturation - INFO - Detected 1716 saturated pixels
# 2021-01-31 20:36:59,211 - stpipe.DarkPipeline.saturation - INFO - Detected 436078 A/D floor pixels
# 2021-01-31 20:36:59,215 - stpipe.DarkPipeline.saturation - INFO - Step saturation done
# 2021-01-31 20:36:59,398 - stpipe.DarkPipeline.ipc - INFO - Step ipc running with args (<RampModel(3, 50, 1024, 1032) from jw00001001001_01101_00001_mirimage_uncal.fits>,).
# 2021-01-31 20:36:59,399 - stpipe.DarkPipeline.ipc - INFO - Step ipc parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '/data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-1/test_miri_dark_pipeline0'}
# 2021-01-31 20:36:59,399 - stpipe.DarkPipeline.ipc - INFO - Step skipped.
# 2021-01-31 20:36:59,399 - stpipe.DarkPipeline.ipc - INFO - Step ipc done
# 2021-01-31 20:36:59,474 - stpipe.DarkPipeline.firstframe - INFO - Step firstframe running with args (<RampModel(3, 50, 1024, 1032) from jw00001001001_01101_00001_mirimage_uncal.fits>,).
# 2021-01-31 20:36:59,475 - stpipe.DarkPipeline.firstframe - INFO - Step firstframe parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-1/test_miri_dark_pipeline0'}
# 2021-01-31 20:37:00,445 - stpipe.DarkPipeline.firstframe - INFO - Step firstframe done
# 2021-01-31 20:37:00,595 - stpipe.DarkPipeline.lastframe - INFO - Step lastframe running with args (<RampModel(3, 50, 1024, 1032) from jw00001001001_01101_00001_mirimage_uncal.fits>,).
# 2021-01-31 20:37:00,596 - stpipe.DarkPipeline.lastframe - INFO - Step lastframe parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-1/test_miri_dark_pipeline0'}
# 2021-01-31 20:37:01,563 - stpipe.DarkPipeline.lastframe - INFO - Step lastframe done
# 2021-01-31 20:37:01,723 - stpipe.DarkPipeline.linearity - INFO - Step linearity running with args (<RampModel(3, 50, 1024, 1032) from jw00001001001_01101_00001_mirimage_uncal.fits>,).
# 2021-01-31 20:37:01,724 - stpipe.DarkPipeline.linearity - INFO - Step linearity parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-1/test_miri_dark_pipeline0'}
# 2021-01-31 20:37:01,734 - stpipe.DarkPipeline.linearity - INFO - Using Linearity reference file /grp/crds/cache/references/jwst/jwst_miri_linearity_0024.fits
# 2021-01-31 20:37:04,294 - stpipe.DarkPipeline.linearity - INFO - Step linearity done
# 2021-01-31 20:37:04,447 - stpipe.DarkPipeline.rscd - INFO - Step rscd running with args (<RampModel(3, 50, 1024, 1032) from jw00001001001_01101_00001_mirimage_uncal.fits>,).
# 2021-01-31 20:37:04,448 - stpipe.DarkPipeline.rscd - INFO - Step rscd parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-1/test_miri_dark_pipeline0', 'type': 'baseline'}
# 2021-01-31 20:37:04,457 - stpipe.DarkPipeline.rscd - INFO - Using RSCD reference file /grp/crds/cache/references/jwst/jwst_miri_rscd_0010.fits
# 2021-01-31 20:37:05,460 - stpipe.DarkPipeline.rscd - INFO - Step rscd done
# 2021-01-31 20:37:05,460 - stpipe.DarkPipeline - INFO - ... ending calwebb_dark
# 2021-01-31 20:37:06,324 - stpipe.DarkPipeline - INFO - Saved model in jw00001001001_01101_00001_mirimage_dark.fits
# 2021-01-31 20:37:06,324 - stpipe.DarkPipeline - INFO - Step DarkPipeline done
# ------------------------------ Captured log call -------------------------------
# DEBUG    stpipe:connectionpool.py:971 Starting new HTTPS connection (1): bytesalad.stsci.edu:443
# DEBUG    stpipe:connectionpool.py:971 Starting new HTTPS connection (1): bytesalad.stsci.edu:443
# DEBUG    stpipe:connectionpool.py:452 https://bytesalad.stsci.edu:443 "GET /artifactory HTTP/1.1" 302 0
# DEBUG    stpipe:connectionpool.py:452 https://bytesalad.stsci.edu:443 "GET /artifactory HTTP/1.1" 302 0
# DEBUG    stpipe:connectionpool.py:452 https://bytesalad.stsci.edu:443 "GET /artifactory/ HTTP/1.1" 302 0
# DEBUG    stpipe:connectionpool.py:452 https://bytesalad.stsci.edu:443 "GET /artifactory/ HTTP/1.1" 302 0
# DEBUG    stpipe:connectionpool.py:452 https://bytesalad.stsci.edu:443 "GET /ui/ HTTP/1.1" 200 1196
# DEBUG    stpipe:connectionpool.py:452 https://bytesalad.stsci.edu:443 "GET /ui/ HTTP/1.1" 200 1196
# DEBUG    stpipe:connectionpool.py:971 Starting new HTTPS connection (1): bytesalad.stsci.edu:443
# DEBUG    stpipe:connectionpool.py:971 Starting new HTTPS connection (1): bytesalad.stsci.edu:443
# DEBUG    stpipe:connectionpool.py:452 https://bytesalad.stsci.edu:443 "GET /artifactory/jwst-pipeline/dev/miri/image/jw00001001001_01101_00001_mirimage_uncal.fits HTTP/1.1" 200 1589420160
# DEBUG    stpipe:connectionpool.py:452 https://bytesalad.stsci.edu:443 "GET /artifactory/jwst-pipeline/dev/miri/image/jw00001001001_01101_00001_mirimage_uncal.fits HTTP/1.1" 200 1589420160
# DEBUG    stpipe:connectionpool.py:971 Starting new HTTPS connection (1): bytesalad.stsci.edu:443
# DEBUG    stpipe:connectionpool.py:971 Starting new HTTPS connection (1): bytesalad.stsci.edu:443
# DEBUG    stpipe:connectionpool.py:452 https://bytesalad.stsci.edu:443 "GET /artifactory/jwst-pipeline/dev/miri/image/jw00001001001_01101_00001_mirimage_uncal.fits HTTP/1.1" 200 1589420160
# DEBUG    stpipe:connectionpool.py:452 https://bytesalad.stsci.edu:443 "GET /artifactory/jwst-pipeline/dev/miri/image/jw00001001001_01101_00001_mirimage_uncal.fits HTTP/1.1" 200 1589420160
# DEBUG    stpipe:config_parser.py:145 Config file did not parse as ASDF. Trying as ConfigObj: config/calwebb_dark.cfg
# DEBUG    stpipe:config_parser.py:145 Config file did not parse as ASDF. Trying as ConfigObj: config/calwebb_dark.cfg
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:pipeline.py:194 Retrieving all substep parameters from CRDS
# DEBUG    stpipe:pipeline.py:194 Retrieving all substep parameters from CRDS
# DEBUG    stpipe:util.py:188 Opening /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-1/test_miri_dark_pipeline0/jw00001001001_01101_00001_mirimage_uncal.fits as <class 'jwst.datamodels.ramp.RampModel'>
# DEBUG    stpipe:util.py:188 Opening /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-1/test_miri_dark_pipeline0/jw00001001001_01101_00001_mirimage_uncal.fits as <class 'jwst.datamodels.ramp.RampModel'>
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "SKIP_FITS_UPDATE" cannot be found. Using default value of "None".
# DEBUG    stpipe:util.py:175 Environmental "SKIP_FITS_UPDATE" cannot be found. Using default value of "None".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "VALIDATE_ON_ASSIGNMENT" cannot be found. Using default value of "True".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# DEBUG    stpipe:util.py:175 Environmental "STRICT_VALIDATION" cannot be found. Using default value of "False".
# ...
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_image.py::test_miri_image_image3[a3001_crf]
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_image.py::test_miri_image_image3[a3001_crf]
#   /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/skymatch/skyimage.py:258: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
#   Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#     ys = np.linspace(-0.5, ny - 0.5, ninty, dtype=np.float)[1:-1]
#
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_image.py::test_miri_image_image3[a3001_crf]
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_image.py::test_miri_image_image3[a3001_crf]
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_image.py::test_miri_image_image3[a3001_crf]
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_image.py::test_miri_image_image3[a3001_crf]
#   /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/skymatch/skyimage.py:264: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
#   Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#     borderx = np.empty((npts + 1,), dtype=np.float)
#
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_image.py::test_miri_image_image3[a3001_crf]
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_image.py::test_miri_image_image3[a3001_crf]
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_image.py::test_miri_image_image3[a3001_crf]
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_image.py::test_miri_image_image3[a3001_crf]
#   /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/skymatch/skyimage.py:265: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
#   Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#     bordery = np.empty((npts + 1,), dtype=np.float)
#
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_image.py::test_miri_image_image3[a3001_crf]
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slit_spec3.py::test_miri_lrs_slit_spec3[s2d]
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slitless.py::test_miri_lrs_slitless_tso3[outlier_detection]
#   /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1113: RuntimeWarning: All-NaN slice encountered
#     r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
#
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_image.py::test_miri_image_image3[a3001_crf]
#   /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/outlier_detection/outlier_detection.py:424: RuntimeWarning: overflow encountered in square
#     ta = np.sqrt(np.abs(blot_data) + err_data ** 2)
#
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_dedicated_mbkg.py: 1 warning
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_nod_masterbg.py: 1 warning
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slit_spec2.py: 1 warning
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slit_spec3.py: 1 warning
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slitless.py: 20 warnings
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_dedicated_mbkg.py: 1 warning
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_extract1d.py: 1 warning
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_nod_masterbg.py: 1 warning
#   /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/extract_1d/spec_wcs.py:48: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
#   Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#     pixel = np.arange(len(wavelength), dtype=np.float)
#
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_dedicated_mbkg.py: 5 warnings
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_masterbg_user.py: 5 warnings
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_nod_masterbg.py: 10 warnings
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slit_spec3.py: 24 warnings
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_dedicated_mbkg.py: 15 warnings
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_nod_masterbg.py: 10 warnings
#   /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/transforms/models.py:610: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
#   Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#     matrix = np.zeros((3, 3), dtype=np.float)
#
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slit_spec2.py::test_miri_lrs_slit_spec2[bsub]
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slitless.py::test_miri_lrs_slitless_tso_spec2[flat_field]
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slitless.py::test_miri_lrs_slitless_tso3[outlier_detection]
#   /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/extract_1d/extract.py:1894: RuntimeWarning: Mean of empty slice
#     wavelength = np.nanmean(wl[sy0:sy1, sx0:sx1], axis=1)
#
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slitless.py::test_miri_lrs_slitless_tso1[dq_init]
#   /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/datamodels/util.py:202: NoTypeWarning: model_type not found. Opening /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/tmp/pytest-of-iraf/pytest-1/test_miri_lrs_slitless_run_tso1_pipeline0/jw00623026001_03106_00005_mirimage_uncal.fits as a RampModel
#     warnings.warn(f"model_type not found. Opening {file_name} as a {class_name}",
#
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_dedicated_mbkg.py: 10 warnings
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_nod_masterbg.py: 7 warnings
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_tso.py: 1 warning
#   /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/gwcs/selector.py:185: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
#   Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#     mapper = np.asanyarray(mapper, dtype=np.int)
#
# miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_tso.py::test_spec2[assign_wcs]
#   /data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/gwcs/geometry.py:203: RuntimeWarning: invalid value encountered in remainder
#     lon = np.mod(lon, 360.0 * u.deg if nquant else 360.0)
#
# -- Docs: https://docs.pytest.org/en/stable/warnings.html
# - generated html file: file:///data1/jenkins/workspace/Notebooks/jwst_validation_notebooks_spacetelescope/jwst_validation_notebooks/regression_test/tmpdir/regtest_report.html -
# =========================== short test summary info ============================
# FAILED ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_dark.py::test_miri_dark_pipeline
# FAILED ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_image.py::test_miri_image3_i2d
# FAILED ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_masterbg_user.py::test_miri_lrs_masterbg_user
# FAILED ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slit_spec2.py::test_miri_lrs_slit_spec2[bsub]
# FAILED ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slit_spec2.py::test_miri_lrs_slit_spec2[flat_field]
# FAILED ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slit_spec2.py::test_miri_lrs_slit_spec2[assign_wcs]
# FAILED ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slit_spec2.py::test_miri_lrs_slit_spec2[srctype]
# FAILED ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slit_spec2.py::test_miri_lrs_slit_spec2[cal]
# FAILED ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slit_spec2.py::test_miri_lrs_slit_spec2[x1d]
# FAILED ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slit_spec3.py::test_miri_lrs_slit_spec3[s2d]
# FAILED ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slit_spec3.py::test_miri_lrs_slit_spec3[x1d]
# FAILED ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slitless.py::test_miri_lrs_slitless_tso1[dq_init]
# FAILED ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slitless.py::test_miri_lrs_slitless_tso1[saturation]
# FAILED ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slitless.py::test_miri_lrs_slitless_tso1[refpix]
# FAILED ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slitless.py::test_miri_lrs_slitless_tso1[linearity]
# FAILED ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slitless.py::test_miri_lrs_slitless_tso1[dark_current]
# FAILED ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slitless.py::test_miri_lrs_slitless_tso1[jump]
# FAILED ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slitless.py::test_miri_lrs_slitless_tso1[rate]
# FAILED ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slitless.py::test_miri_lrs_slitless_tso1[rateints]
# FAILED ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slitless.py::test_miri_lrs_slitless_tso_spec2[flat_field]
# FAILED ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slitless.py::test_miri_lrs_slitless_tso_spec2[srctype]
# FAILED ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slitless.py::test_miri_lrs_slitless_tso_spec2[calints]
# FAILED ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slitless.py::test_miri_lrs_slitless_tso_spec2[assign_wcs]
# FAILED ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slitless.py::test_miri_lrs_slitless_tso_spec2[x1dints]
# FAILED ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slitless.py::test_miri_lrs_slitless_tso3[outlier_detection]
# FAILED ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slitless.py::test_miri_lrs_slitless_tso3[crfints]
# FAILED ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_lrs_slitless.py::test_miri_lrs_slitless_tso3_x1dints
# FAILED ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_tso.py::test_spec2[assign_wcs]
# FAILED ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_tso.py::test_spec2[calints]
# FAILED ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_tso.py::test_spec2[flat_field]
# FAILED ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_tso.py::test_spec2[fringe]
# FAILED ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_tso.py::test_spec2[photom]
# FAILED ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_mrs_tso.py::test_spec2[srctype]
# FAILED ../../miniconda3/envs/jwst_validation_notebooks/lib/python3.9/site-packages/jwst/regtest/test_miri_setpointing.py::test_miri_setpointing
# = 34 failed, 31 passed, 25 skipped, 357 deselected, 489 warnings in 372.69s (0:06:12) =

# %%
report
# Out:
#         <iframe
#             width="700"
#             height="600"
#             src="tmpdir/regtest_report.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# <a id="about"></a>
# ## About This Notebook
# **Author:** Alicia Canipe, Staff Scientist, NIRCam
# <br>**Updated On:** 01/27/2021

# %% [markdown]
# [Top of Page](#title_ID)
# <img style="float: right;" src="./stsci_pri_combo_mark_horizonal_white_bkgd.png" alt="stsci_pri_combo_mark_horizonal_white_bkgd" width="200px"/>
